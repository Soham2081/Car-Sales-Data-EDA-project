# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
# LOADING DATASET

df = pd.read_csv(r"C:\Users\Soham Desai\Downloads\cars_data.csv")

# pd.read_json

# %%
# Exploring the data

# %%
df.head(10)
# Out:
#    Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 0        1  2023-07-28     Honda     Amaze  Electric    Automatic
# 1        2  2023-07-30  Mahindra      Thar    Diesel       Manual
# 2        3  2023-07-30     Honda      City  Electric    Automatic
# 3        4  2023-02-12      Tata     Tiago  Electric    Automatic
# 4        5  2023-02-27     Honda     Amaze  Electric       Manual
# 5        6  2023-09-12     Honda      City    Diesel       Manual
# 6        7  2023-04-09     Honda     Amaze  Electric    Automatic
# 7        8  2023-01-24   Hyundai       i10  Electric       Manual
# 8        9  2023-07-07     Honda      Jazz    Petrol    Automatic
# 9       10  2023-01-24  Mahindra   Scorpio  Electric    Automatic
#
#    Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 0      2636520    Chennai  Individual                 2018            19.6
# 1      1067639     Mumbai      Dealer                 2022            17.3
# ...

# %%
df.tail()
# Out:
#      Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 495      496  2023-12-03   Hyundai     Verna       CNG    Automatic
# 496      497  2023-01-13   Hyundai       i10    Petrol    Automatic
# 497      498  2023-03-12      Tata   Harrier  Electric    Automatic
# 498      499  2023-12-21   Hyundai     Creta    Petrol    Automatic
# 499      500  2023-11-20    Maruti     Dzire  Electric    Automatic
#
#      Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 495      1798782     Mumbai      Dealer                 2020            23.4
# 496       505073  Hyderabad      Dealer                 2016            11.1
# 497      1459012  Hyderabad      Dealer                 2015            12.7
# 498      2512166  Hyderabad  Individual                 2020            13.1
# 499       977102  Hyderabad      Dealer                 2016            13.3
#
#      Engine Capacity (cc)
# 495                  1500
# 496                  1800
# ...

# %%
df.shape
# Out:
# (500, 12)

# %%
df.columns
# Out:
# Index(['Sale ID', 'Date', 'Car Brand', 'Car Model', 'Fuel Type',
#        'Transmission', 'Price (INR)', 'City', 'Seller Type',
#        'Year of Manufacture', 'Mileage (km/l)', 'Engine Capacity (cc)'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Sale ID   Price (INR)  Year of Manufacture  Mileage (km/l)  \
# count  500.000000  5.000000e+02           500.000000      500.000000
# mean   250.500000  1.715120e+06          2019.066000       17.303400
# std    144.481833  8.084176e+05             2.622097        4.250805
# min      1.000000  3.065960e+05          2015.000000       10.000000
# 25%    125.750000  9.786890e+05          2017.000000       13.500000
# 50%    250.500000  1.765048e+06          2019.000000       17.200000
# 75%    375.250000  2.465958e+06          2021.000000       21.100000
# max    500.000000  2.998496e+06          2023.000000       25.000000
#
#        Engine Capacity (cc)
# count             500.00000
# mean             1671.60000
# std               502.25288
# min              1000.00000
# 25%              1200.00000
# 50%              1500.00000
# 75%              2000.00000
# max              2500.00000

# %%
print(df['Car Brand'])
# Out:
# 0         Honda
# 1      Mahindra
# 2         Honda
# 3          Tata
# 4         Honda
#          ...
# 495     Hyundai
# 496     Hyundai
# 497        Tata
# 498     Hyundai
# 499      Maruti
# Name: Car Brand, Length: 500, dtype: object

# %%
df.info() # this gives you the meta data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Sale ID               500 non-null    int64
#  1   Date                  500 non-null    object
#  2   Car Brand             500 non-null    object
#  3   Car Model             500 non-null    object
#  4   Fuel Type             500 non-null    object
#  5   Transmission          500 non-null    object
#  6   Price (INR)           500 non-null    int64
#  7   City                  500 non-null    object
#  8   Seller Type           500 non-null    object
#  9   Year of Manufacture   500 non-null    int64
#  10  Mileage (km/l)        500 non-null    float64
#  11  Engine Capacity (cc)  500 non-null    int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 47.0+ KB

# %%
df.describe() # it gives you the statistics of the data
# Out:
#           Sale ID   Price (INR)  Year of Manufacture  Mileage (km/l)  \
# count  500.000000  5.000000e+02           500.000000      500.000000
# mean   250.500000  1.715120e+06          2019.066000       17.303400
# std    144.481833  8.084176e+05             2.622097        4.250805
# min      1.000000  3.065960e+05          2015.000000       10.000000
# 25%    125.750000  9.786890e+05          2017.000000       13.500000
# 50%    250.500000  1.765048e+06          2019.000000       17.200000
# 75%    375.250000  2.465958e+06          2021.000000       21.100000
# max    500.000000  2.998496e+06          2023.000000       25.000000
#
#        Engine Capacity (cc)
# count             500.00000
# mean             1671.60000
# std               502.25288
# min              1000.00000
# 25%              1200.00000
# 50%              1500.00000
# 75%              2000.00000
# max              2500.00000

# %%
df.isnull()
# Out:
#      Sale ID   Date  Car Brand  Car Model  Fuel Type  Transmission  \
# 0      False  False      False      False      False         False
# 1      False  False      False      False      False         False
# 2      False  False      False      False      False         False
# 3      False  False      False      False      False         False
# 4      False  False      False      False      False         False
# ..       ...    ...        ...        ...        ...           ...
# 495    False  False      False      False      False         False
# 496    False  False      False      False      False         False
# 497    False  False      False      False      False         False
# 498    False  False      False      False      False         False
# 499    False  False      False      False      False         False
#
#      Price (INR)   City  Seller Type  Year of Manufacture  Mileage (km/l)  \
# 0          False  False        False                False           False
# ...

# %%
print(df.isnull().sum()) # gives us the total number of the null values in the columns
# Out:
# Sale ID                 0
# Date                    0
# Car Brand               0
# Car Model               0
# Fuel Type               0
# Transmission            0
# Price (INR)             0
# City                    0
# Seller Type             0
# Year of Manufacture     0
# Mileage (km/l)          0
# Engine Capacity (cc)    0
# dtype: int64

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 0          1  2023-07-28     Honda     Amaze  Electric    Automatic
# 1          2  2023-07-30  Mahindra      Thar    Diesel       Manual
# 2          3  2023-07-30     Honda      City  Electric    Automatic
# 3          4  2023-02-12      Tata     Tiago  Electric    Automatic
# 4          5  2023-02-27     Honda     Amaze  Electric       Manual
# ..       ...         ...       ...       ...       ...          ...
# 495      496  2023-12-03   Hyundai     Verna       CNG    Automatic
# 496      497  2023-01-13   Hyundai       i10    Petrol    Automatic
# 497      498  2023-03-12      Tata   Harrier  Electric    Automatic
# 498      499  2023-12-21   Hyundai     Creta    Petrol    Automatic
# 499      500  2023-11-20    Maruti     Dzire  Electric    Automatic
#
#      Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# ...

# %%
print(df['Car Brand'].head())
# Out:
# 0       Honda
# 1    Mahindra
# 2       Honda
# 3        Tata
# 4       Honda
# Name: Car Brand, dtype: object

# %%
print(df[['Car Brand','Price (INR)']].head())
# Out:
#   Car Brand  Price (INR)
# 0     Honda      2636520
# 1  Mahindra      1067639
# 2     Honda      2832014
# 3      Tata      2636617
# 4     Honda      2501019

# %%
print(df[df['Price (INR)'] > 1000000].head())
# Out:
#    Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 0        1  2023-07-28     Honda     Amaze  Electric    Automatic
# 1        2  2023-07-30  Mahindra      Thar    Diesel       Manual
# 2        3  2023-07-30     Honda      City  Electric    Automatic
# 3        4  2023-02-12      Tata     Tiago  Electric    Automatic
# 4        5  2023-02-27     Honda     Amaze  Electric       Manual
#
#    Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 0      2636520    Chennai  Individual                 2018            19.6
# 1      1067639     Mumbai      Dealer                 2022            17.3
# 2      2832014  Bangalore      Dealer                 2019            13.6
# 3      2636617     Mumbai  Individual                 2016            16.3
# 4      2501019      Delhi      Dealer                 2022            21.1
#
#    Engine Capacity (cc)
# 0                  1200
# 1                  1500
# 2                  1000
# ...

# %%
print(df[df['Car Brand'] == 'Honda'].head())
# Out:
#    Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 0        1  2023-07-28     Honda     Amaze  Electric    Automatic
# 2        3  2023-07-30     Honda      City  Electric    Automatic
# 4        5  2023-02-27     Honda     Amaze  Electric       Manual
# 5        6  2023-09-12     Honda      City    Diesel       Manual
# 6        7  2023-04-09     Honda     Amaze  Electric    Automatic
#
#    Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 0      2636520    Chennai  Individual                 2018            19.6
# 2      2832014  Bangalore      Dealer                 2019            13.6
# 4      2501019      Delhi      Dealer                 2022            21.1
# 5      2522517  Bangalore      Dealer                 2020            21.2
# 6      1763668      Delhi      Dealer                 2023            22.6
#
#    Engine Capacity (cc)
# 0                  1200
# 2                  1000
# 4                  1000
# ...

# %%
### To replace null values we use the mean median and the mode,

# %%
df['Price (INR)'] = df['Price (INR)'].fillna(df['Price (INR)'].mean())

# %%
df['Fuel Type'] = df['Fuel Type'].fillna(df['Fuel Type'].mode()[0])

# %%
! pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
df['Price (INR)'].plot.box()
plt.show()

# %%
# IQR

Q1 = df['Price (INR)'].quantile(0.25)
Q2 = df['Price (INR)'].quantile(0.75)

IQR = Q2 - Q1



outlier = df[(df['Price (INR)'] < (Q1 - 1.5*IQR))]

# %%
print(df.groupby('Car Brand')['Price (INR)'].mean()) # avreage price by car brand
# Out:
# Car Brand
# Honda       1.664649e+06
# Hyundai     1.711483e+06
# Mahindra    1.729867e+06
# Maruti      1.753339e+06
# Tata        1.722261e+06
# Name: Price (INR), dtype: float64

# %%
print(df.groupby('Fuel Type')['Sale ID'].count())
# Out:
# Fuel Type
# CNG         131
# Diesel      115
# Electric    132
# Petrol      122
# Name: Sale ID, dtype: int64

# %%
pivote = pd.pivot_table(df , values= 'Price (INR)' , index = 'Car Brand' , columns = 'Fuel Type' , aggfunc = 'mean')
print(pivote)
# Out:
# Fuel Type           CNG        Diesel      Electric        Petrol
# Car Brand
# Honda      1.595492e+06  1.530610e+06  1.815890e+06  1.627315e+06
# Hyundai    1.698307e+06  1.422946e+06  2.091538e+06  1.611260e+06
# Mahindra   1.884176e+06  2.045043e+06  1.829489e+06  1.305651e+06
# Maruti     1.777758e+06  1.817554e+06  1.631250e+06  1.775247e+06
# Tata       1.826986e+06  1.479491e+06  1.838095e+06  1.767893e+06

# %%
offers = pd.DataFrame({
    'Car Brand' : ['Maruti' , 'Honda' , 'Hyundai'],
    'Discount' : [50000 , 30000 , 40000]
})

# %%
merged = pd.merge(df,offers, on= 'Car Brand', how = 'left')
print(merged.head())
# Out:
#    Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 0        1  2023-07-28     Honda     Amaze  Electric    Automatic
# 1        2  2023-07-30  Mahindra      Thar    Diesel       Manual
# 2        3  2023-07-30     Honda      City  Electric    Automatic
# 3        4  2023-02-12      Tata     Tiago  Electric    Automatic
# 4        5  2023-02-27     Honda     Amaze  Electric       Manual
#
#    Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 0      2636520    Chennai  Individual                 2018            19.6
# 1      1067639     Mumbai      Dealer                 2022            17.3
# 2      2832014  Bangalore      Dealer                 2019            13.6
# 3      2636617     Mumbai  Individual                 2016            16.3
# 4      2501019      Delhi      Dealer                 2022            21.1
#
#    Engine Capacity (cc)  Discount
# 0                  1200   30000.0
# 1                  1500       NaN
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
# Out:
# C:\Users\Soham Desai\AppData\Local\Temp\ipykernel_10296\1929413170.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
df.head()
# Out:
#    Sale ID       Date Car Brand Car Model Fuel Type Transmission  Price (INR)  \
# 0        1 2023-07-28     Honda     Amaze  Electric    Automatic      2636520
# 1        2 2023-07-30  Mahindra      Thar    Diesel       Manual      1067639
# 2        3 2023-07-30     Honda      City  Electric    Automatic      2832014
# 3        4 2023-02-12      Tata     Tiago  Electric    Automatic      2636617
# 4        5 2023-02-27     Honda     Amaze  Electric       Manual      2501019
#
#         City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 0    Chennai  Individual                 2018            19.6
# 1     Mumbai      Dealer                 2022            17.3
# 2  Bangalore      Dealer                 2019            13.6
# 3     Mumbai  Individual                 2016            16.3
# 4      Delhi      Dealer                 2022            21.1
#
#    Engine Capacity (cc)  Year  Month
# 0                  1200  2023      7
# 1                  1500  2023      7
# ...

# %%
df.to_csv("car_sales_cleaned.csv",index=False)
